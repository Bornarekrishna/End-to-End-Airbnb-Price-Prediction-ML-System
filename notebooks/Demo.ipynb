# %%
# Download the dataset
# !kaggle datasets download -d salonijaroli/airbnb-price -p K:\End-to-End-Airbnb-Price-Prediction-ML-System\data\raw
# Out:
# Dataset URL: https://www.kaggle.com/datasets/salonijaroli/airbnb-price
# License(s): unknown
# ...
#   0%|          | 0.00/31.3M [00:00<?, ?B/s]
#   3%|▎         | 1.00M/31.3M [00:03<01:44, 304kB/s]
#   6%|▋         | 2.00M/31.3M [00:05<01:15, 406kB/s]
#  10%|▉         | 3.00M/31.3M [00:09<01:33, 317kB/s]
#  13%|█▎        | 4.00M/31.3M [00:17<02:16, 209kB/s]
#  16%|█▌        | 5.00M/31.3M [00:26<02:54, 157kB/s]
#  19%|█▉        | 6.00M/31.3M [00:39<03:42, 119kB/s]
#  22%|██▏       | 7.00M/31.3M [00:44<03:00, 141kB/s]
#  26%|██▌       | 8.00M/31.3M [00:47<02:19, 175kB/s]
#  29%|██▉       | 9.00M/31.3M [00:50<01:53, 205kB/s]
#  32%|███▏      | 10.0M/31.3M [00:53<01:31, 243kB/s]
#  35%|███▌      | 11.0M/31.3M [00:55<01:13, 288kB/s]
#  38%|███▊      | 12.0M/31.3M [00:59<01:15, 268kB/s]
#  42%|████▏     | 13.0M/31.3M [01:02<01:04, 299kB/s]
#  45%|████▍     | 14.0M/31.3M [01:04<00:53, 338kB/s]
#  48%|████▊     | 15.0M/31.3M [01:07<00:52, 324kB/s]
# ...

# %%
# Unzip file 
import zipfile 

zip_ref = zipfile.ZipFile(r'K:\End-to-End-Airbnb-Price-Prediction-ML-System\data\raw\airbnb-price.zip') 
zip_ref.extractall(r'K:\End-to-End-Airbnb-Price-Prediction-ML-System\data\raw') 
zip_ref.close()
print("The CSV file successfully stored in the Data/row folder")
# Out:
# The CSV file successfully stored in the Data/row folder
